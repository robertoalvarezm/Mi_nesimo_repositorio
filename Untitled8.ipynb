# %% [markdown]
# <a href="https://colab.research.google.com/github/robertoalvarezm/Mi_nesimo_repositorio/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x<-runif(100)
hist(x)
# Out:
# Plot with title “Histogram of x”

# %%
x<-3
